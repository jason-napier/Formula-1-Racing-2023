# %%
from webdriver_manager.chrome import ChromeDriverManager

from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
pip install webdriver_manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=True)

# %%
# Visit the Formula 1 site for salaries
url = 'https://www.sportingnews.com/us/formula-1/news/how-much-f1-drivers-paid-salaries-teams-2023/kr2jqdm7hofmbpyohlckmuy5'
browser.visit(url)

# %%
html = soup(browser.html, 'html.parser')

# %%
table = html.find('div', class_='table-container')
table
# Out:
# <div class="table-container"><table border="1" cellpadding="1" cellspacing="1" style="width: 500px;"><caption><strong>2023 F1 Driver Salaries</strong></caption>
# <tbody><tr><td class="text-align-center"><strong>Driver</strong></td>
# <td class="text-align-center"><strong>Team</strong></td>
# <td class="text-align-center"><strong>Salary</strong></td>
# <td class="text-align-center"><strong>Age</strong></td>
# </tr><tr><td class="text-align-center">Max Verstappen</td>
# <td class="text-align-center">Red Bull</td>
# <td class="text-align-center">$55M</td>
# <td class="text-align-center">25</td>
# </tr><tr><td class="text-align-center">Lewis Hamilton</td>
# <td class="text-align-center">Mercedes</td>
# <td class="text-align-center">$35M</td>
# <td class="text-align-center">38</td>
# </tr><tr><td class="text-align-center">Charles Leclerc</td>
# <td class="text-align-center">Ferrari</td>
# <td class="text-align-center">$24M</td>
# <td class="text-align-center">25</td>
# ...

# %%
# Create a dataframe from the table 
df = pd.read_html(str(table))[0]
df
# Out:
#                   0             1       2    3
# 0            Driver          Team  Salary  Age
# 1    Max Verstappen      Red Bull    $55M   25
# 2    Lewis Hamilton      Mercedes    $35M   38
# 3   Charles Leclerc       Ferrari    $24M   25
# 4      Lando Norris       McLaren    $20M   23
# 5      Carlos Sainz       Ferrari    $12M   28
# 6      Sergio Perez      Red Bull    $10M   33
# 7   Valterri Bottas    Alfa Romeo    $10M   33
# 8    George Russell      Mercedes     $8M   25
# 9      Esteban Ocon        Alpine     $6M   26
# 10     Pierre Gasly        Alpine     $5M   27
# 11  Fernando Alonso  Aston Martin     $5M   41
# 12  Kevin Magnussen          Haas     $5M   30
# 13       Alex Albon      Williams     $3M   26
# 14    Oscar Piastri       McLaren     $2M   21
# 15     Lance Stroll  Aston Martin     $2M   24
# 16      Guanyu Zhou    Alfa Romeo     $2M   23
# 17    Nyck de Vries    AlphaTauri     $2M   28
# 18  Nico Hülkenburg    AlphaTauri     $1M   35
# ...

# %%
#change column names
df.columns = ['Driver', 'Team', 'Salary', 'Age']
df
# Out:
#              Driver          Team Salary Age
# 1    Max Verstappen      Red Bull   $55M  25
# 2    Lewis Hamilton      Mercedes   $35M  38
# 3   Charles Leclerc       Ferrari   $24M  25
# 4      Lando Norris       McLaren   $20M  23
# 5      Carlos Sainz       Ferrari   $12M  28
# 6      Sergio Perez      Red Bull   $10M  33
# 7   Valterri Bottas    Alfa Romeo   $10M  33
# 8    George Russell      Mercedes    $8M  25
# 9      Esteban Ocon        Alpine    $6M  26
# 10     Pierre Gasly        Alpine    $5M  27
# 11  Fernando Alonso  Aston Martin    $5M  41
# 12  Kevin Magnussen          Haas    $5M  30
# 13       Alex Albon      Williams    $3M  26
# 14    Oscar Piastri       McLaren    $2M  21
# 15     Lance Stroll  Aston Martin    $2M  24
# 16      Guanyu Zhou    Alfa Romeo    $2M  23
# 17    Nyck de Vries    AlphaTauri    $2M  28
# 18  Nico Hülkenburg    AlphaTauri    $1M  35
# 19     Yuki Tsunoda    AlphaTauri    $1M  22
# 20   Logan Sargeant      Williams    $1M  22

# %%
#export as csv  
df.to_csv('f1_salaries.csv', index=False)
