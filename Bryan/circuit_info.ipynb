# %%
#Dependencies
import json
import os
import pandas as pd

# Load JSON
filepath = os.path.join("..","Lucas", "circuits.json")
with open(filepath) as jsonfile:
    circuit_data = json.load(jsonfile)

# %%
df = pd.read_json('../Lucas/circuits.json', orient='records')
df.head()
# Out:
#      circuitId                                                url  \
# 0     adelaide  http://en.wikipedia.org/wiki/Adelaide_Street_C...
# 1     ain-diab      http://en.wikipedia.org/wiki/Ain-Diab_Circuit
# 2      aintree  http://en.wikipedia.org/wiki/Aintree_Motor_Rac...
# 3  albert_park  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 4     americas  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
#
#                       circuitName  \
# 0         Adelaide Street Circuit
# 1                        Ain Diab
# 2                         Aintree
# 3  Albert Park Grand Prix Circuit
# 4         Circuit of the Americas
#
#                                             Location
# 0  {'lat': '-34.9272', 'long': '138.617', 'locali...
# 1  {'lat': '33.5786', 'long': '-7.6875', 'localit...
# 2  {'lat': '53.4769', 'long': '-2.94056', 'locali...
# 3  {'lat': '-37.8497', 'long': '144.968', 'locali...
# 4  {'lat': '30.1328', 'long': '-97.6411', 'locali...

# %%
# extract circuitName, lat, long, locality, country
df = df[['circuitName', 'Location']]
df.head()
# Out:
#                       circuitName  \
# 0         Adelaide Street Circuit
# 1                        Ain Diab
# 2                         Aintree
# 3  Albert Park Grand Prix Circuit
# 4         Circuit of the Americas
#
#                                             Location
# 0  {'lat': '-34.9272', 'long': '138.617', 'locali...
# 1  {'lat': '33.5786', 'long': '-7.6875', 'localit...
# 2  {'lat': '53.4769', 'long': '-2.94056', 'locali...
# 3  {'lat': '-37.8497', 'long': '144.968', 'locali...
# 4  {'lat': '30.1328', 'long': '-97.6411', 'locali...

# %%
# break out location into lat, long, locality, country
df = pd.concat([df.drop(['Location'], axis=1), df['Location'].apply(pd.Series)], axis=1)
df.head()
# Out:
#                       circuitName       lat      long    locality    country
# 0         Adelaide Street Circuit  -34.9272   138.617    Adelaide  Australia
# 1                        Ain Diab   33.5786   -7.6875  Casablanca    Morocco
# 2                         Aintree   53.4769  -2.94056   Liverpool         UK
# 3  Albert Park Grand Prix Circuit  -37.8497   144.968   Melbourne  Australia
# 4         Circuit of the Americas   30.1328  -97.6411      Austin        USA

# %%
# rename columns
df = df.rename(columns={'circuitName': 'Circuit Name', 'lat': 'Latitude', 'long': 'Longitude', 'locality': 'City', 'country': 'Country'})
df.head()
# Out:
#                      Circuit Name  Latitude Longitude        City    Country
# 0         Adelaide Street Circuit  -34.9272   138.617    Adelaide  Australia
# 1                        Ain Diab   33.5786   -7.6875  Casablanca    Morocco
# 2                         Aintree   53.4769  -2.94056   Liverpool         UK
# 3  Albert Park Grand Prix Circuit  -37.8497   144.968   Melbourne  Australia
# 4         Circuit of the Americas   30.1328  -97.6411      Austin        USA

# %%
# save dataframe to csv
df.to_csv('circuit_info.csv', index=False)
